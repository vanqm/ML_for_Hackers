# %%
import pandas as pd
import numpy as np
from ggplot import *
import os,datetime
import us
from IPython.core.pylabtools import figsize
from matplotlib import pyplot as plt
from pandas.tools.plotting import scatter_matrix
from scipy import stats
from sklearn.linear_model import LogisticRegression
# %matplotlib inline

# %%
heights_weights = pd.read_csv(os.path.join("data", "01_heights_weights_genders.csv"), sep=",")

# %%
heights_weights.Height.describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
def mean(x): 
    """ returns the mean of x (assumes x is a numpy array) """
    return x.mean()

def my_median(x):
    """ returns the median of x (assumes x is a numpy array) """
    return np.median(x)

# %%
mean(heights_weights.Height.values)
# Out:
# 66.367559754821244

# %%
my_median(heights_weights.Height.values)
# Out:
# 66.318070081784654

# %%
my_vector = np.arange(101)

# %%
mean(my_vector)
# Out:
# 50.0

# %%
my_median(my_vector)
# Out:
# 50.0

# %%
my_vector = np.array([0,0,100])

# %%
mean(my_vector)
# Out:
# 33.333333333333336

# %%
my_median(my_vector)
# Out:
# 0.0

# %%
mean(heights_weights.Height.values) - heights_weights.Height.values.mean()
# Out:
# 0.0

# %%
my_median(heights_weights.Height.values) - np.median(heights_weights.Height.values)
# Out:
# 0.0

# %%
heights = heights_weights.Height.values

# %%
heights.min()
# Out:
# 54.263133325097101

# %%
heights.max()
# Out:
# 78.998742346389591

# %%
np.percentile(heights, [0,25,50,75,100])
# Out:
# array([ 54.26313333,  63.50562048,  66.31807008,  69.17426173,  78.99874235])

# %%
np.percentile(heights, [0,20,40,60,80,100])
# Out:
# array([ 54.26313333,  62.85900651,  65.19422136,  67.43537384,
#         69.81162001,  78.99874235])

# %%
def my_var(x):
    """ calculates the variance of x"""
    m = x.mean()
    return ((x-m)**2).sum() / len(x) 
my_var(heights)
# Out:
# 14.80199229287676

# %%
my_var(heights) - np.var(heights)
# Out:
# 0.0

# %%
ggplot(heights_weights, aes(x = 'Height')) + geom_histogram(binwidth = 1)
# Out:
# <ggplot: (273515649)>

# %%
ggplot(heights_weights, aes(x = 'Height')) + geom_histogram(binwidth = 5)
# Out:
# <ggplot: (282069069)>

# %%
ggplot(heights_weights, aes(x = 'Height')) + geom_histogram(binwidth = .1)
# Out:
# <ggplot: (280901373)>

# %%
ggplot(heights_weights, aes(x = 'Height')) + geom_density()
# Out:
# <ggplot: (282619793)>

# %%
ggplot(heights_weights, aes(x = 'Height', fill="Gender")) + geom_density()
# Out:
# <ggplot: (281083001)>

# %%
ggplot(heights_weights, aes(x='Weight', fill="Gender")) + geom_density()
# Out:
# <ggplot: (283234365)>

# %%
ggplot(heights_weights, aes(x='Weight', fill="Gender")) + geom_density() +  facet_grid("Gender")
# Out:
# <ggplot: (273515605)>

# %%
m = 0
std = 1
random_data = std*np.random.randn(100000) + m

# %%
random_data.mean()
# Out:
# -0.00015250108825884241

# %%
np.std(random_data)
# Out:
# 1.0012934420003123

# %%
data = pd.DataFrame({'X' : random_data })

# %%
ggplot(data, aes(x = 'X')) + geom_density()
# Out:
# <ggplot: (283241273)>

# %%
c = pd.DataFrame({"X" : stats.cauchy.rvs(size=1000) });

# %%
n = pd.DataFrame({"X" : np.random.normal(loc=0,scale=1,size=1000) });

# %%
g = pd.DataFrame({"X" : stats.gamma.rvs(1.5,size=1000) });

# %%
ggplot(c, aes(x = 'X')) + geom_density()
# Out:
# <ggplot: (283662693)>

# %%
ggplot(n, aes(x = 'X')) + geom_density()
# Out:
# <ggplot: (283518521)>

# %%
ggplot(g, aes(x = 'X')) + geom_density()
# Out:
# <ggplot: (283518637)>

# %%
ggplot(heights_weights, aes(x = 'Height', y = 'Weight')) + geom_point()
# Out:
# <ggplot: (282920673)>

# %%
ggplot(heights_weights, aes(x = 'Height', y = 'Weight')) + geom_point() + geom_smooth()
# Out:
# <ggplot: (283144749)>

# %%
ggplot(heights_weights[0:20], aes(x = 'Height', y = 'Weight')) + geom_point() + geom_smooth()
# Out:
# <ggplot: (284393005)>

# %%
ggplot(heights_weights[0:200], aes(x = 'Height', y = 'Weight')) + geom_point() + geom_smooth()
# Out:
# <ggplot: (280894161)>

# %%
ggplot(heights_weights[0:2000], aes(x = 'Height', y = 'Weight')) + geom_point() + geom_smooth()
# Out:
# <ggplot: (283227857)>

# %%
ggplot(heights_weights, aes(x='Height', y='Weight',color='Gender')) + \
geom_point()+ \
scale_color_manual(values=['grey','black']) + theme_bw()
# Out:
# <ggplot: (283565373)>

# %%
ggplot(heights_weights, aes(x = 'Height', y = 'Weight', color = 'Gender')) + \
  geom_point()
# Out:
# <ggplot: (283254021)>

# %%
y = pd.factorize(heights_weights["Gender"])[0]

# %%
X = heights_weights[["Weight","Height"]]

# %%
clf = LogisticRegression()
clf.fit(X, y)
(clf.intercept_, clf.coef_)
# Out:
# (array([ 0.00993687]), array([[-0.19679842,  0.47828349]]))

# %%
ggplot(heights_weights, aes(x = 'Height', y = 'Weight',color = 'Gender')) + \
  geom_point() + \
  scale_color_manual(values=['grey','black']) + theme_bw() + \
  stat_abline(intercept = -clf.intercept_[0] / clf.coef_[0][0],
              slope = - clf.coef_[0][1] / clf.coef_[0][0],
              geom = 'abline',
              color = 'black')
# Out:
# <ggplot: (283607177)>
